# %% [markdown]
# <a href="https://colab.research.google.com/github/waa0511waa/0606/blob/main/0509.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
zoo_animals = ["Dog","Cat","Bird","Tiger","Elephant"];

for animal in zoo_animals:
  if animal.startswith("D"):
    print(animal + "s")

for animal in zoo_animals:
  if len(animal) > 5:
    print(animal)
# Out:
# Dogs
# Elephant

# %%
import nltk

nltk.download("popular")
nltk.download("all-corpora")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# ...

# %%
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

import nltk
from nltk.book import *

# 近似字

text1.similar("monstrous")

print("----------我是分隔線--------")

text2.similar("monstrous")

# common_context

print("----------我是分隔線--------")

context = ["monstrous","careful"]

text1.common_contexts(context)
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless
# ----------我是分隔線--------
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly
# ----------我是分隔線--------
# most_and
